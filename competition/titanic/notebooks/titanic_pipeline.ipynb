# %% [markdown]
# # 🚢 Titanic: Machine Learning from Disaster - Workspace
#
# File notebook này là không gian làm việc để bạn tự lập trình theo kế hoạch chi tiết trong `PIPELINE_PLAN.md`.

# %% [markdown]
# ## 1. Environment Setup & Data Loading

# %%
# TODO: Import thư viện, cố định SEED và load dữ liệu train_df, test_df

# %% [markdown]
# ## 2. Exploratory Data Analysis (EDA) & Trực Quan Hóa

# %%
# TODO: Viết code kiểm tra missing values và vẽ các biểu đồ phân tích (theo Mục 5.2 trong PIPELINE_PLAN.md)

# %% [markdown]
# ## 3. Feature Engineering & Preprocessing

# %%
# TODO: Xây dựng hàm biến đổi đặc trưng (Title, FamilySize, Deck, FarePerPerson, Age Imputation)
def build_features(train, test):
    pass

# %% [markdown]
# ## 4. Model Training & Stratified 5-Fold Cross-Validation

# %%
# TODO: Thiết lập Stratified 5-Fold CV và huấn luyện các mô hình (RF, ExtraTrees, XGBoost, LightGBM, CatBoost)

# %% [markdown]
# ## 5. Ensembling & Evaluation (Soft Voting)

# %%
# TODO: Kết hợp dự đoán bằng Soft Voting Ensemble và đánh giá OOF Accuracy

# %% [markdown]
# ## 6. Generate Submission File & Sanity Checks

# %%
# TODO: Xuất file submission.csv và kiểm tra 4 tiêu chuẩn hợp lệ
